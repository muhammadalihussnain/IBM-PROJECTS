# %%
print('Hello from hello-ibm.ipynb!')
a = 10
b = 20
print(f'The sum is: {a + b}')
# Out:
#   File "/tmp/ipykernel_2498/905458023.py", line 4
#     print(f'The sum is: {a + b}'
#                                 ^
# _IncompleteInputError: incomplete input
